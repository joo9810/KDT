# %%
import mysql
import mysql.connector
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt 
import requests 
import numpy as np 
import cv2 
from io import BytesIO
import os
import glob
import joblib

from torchvision import transforms, models, datasets
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.models import ResNet50_Weights
import  torch.nn.functional as F

import MeCab
from konlpy.tag import Okt

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split

import sys
sys.path.append('/Users/anhyojun/WorkSpace/KDT2/MyModule')
from KDTModule import *

# %%
torch.manual_seed(1)

# %%
# # csv -> DataFrame 변환
# df = pd.read_csv('movieDF.csv')
# df.info()

# %%
conn = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'signcity114',
    database = 'MyDB'
)

cursor = conn.cursor()

query = """
SELECT * FROM movie
where genre not like '%, %'
and (genre is not null)
and (poster_link is not null)
and (genre not like '%실험영화%')
and (genre not like '%무성 영화%')
and (genre not like '%단편 영화%')
and (genre not like '%흑백 영화%')
and (poster_link = 'https://image.cine21.com/resize/www1/common/content19_1[X230,330].jpg');"""

df2 = pd.read_sql(query, conn)
df2
# Out:
# /var/folders/ld/7fj1069x6q7fr5894rwywdk40000gn/T/ipykernel_29246/2502298671.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql(query, conn)
#        id               ko_name                                  en_name  \
# 0   11910                    마녀                                Temptress
# 1   11969                 밤의 연인                           Illicit Dreams
# 2   12193                 바디 체크                            Body Language
# 3   12739                  졸업파티      Prom Night IV: Deliver Us from Evil
# 4   12771                  싸이렌서                             The Silencer
# 5   12842                여우의 미소                           Spiando Marina
# 6   12922                   랑데뷰                              Rendez-vous
# 7   13047               흔들리는 유혹                                Play Nice
# 8   13052                 할렘 슈어                             Harem Suare'
# 9   14429               베니스의 열정                 The Comfort Of Strangers
# 10  15480               도쿄 데카당스                          Tokyo Decadence
# 11  17459              마리와네뜨의 생         From the Life of the Marionettes
# 12  18268                   친화력                  The Elective Affinities
# 13  18329                차가운 샤워                             Cold Showers
# 14  18500               후회하지 않아                                No regret
# 15  20148                 스카우트맨                                 Scoutman
# 16  20171             아트 오브 시크릿                            Art of Losing
# 17  20518                 리틀 핑거   A Little Finger and the Forbidden Body
# 18  20553               사랑의 유형지                        Love Never To End
# 19  20933                리틀 칠드런                          Little Children
# 20  21134                   일루전                                 Illusion
# 21  21368               레이디 채털리                          Lady Chatterley
# 22  21848               비스티 보이즈                   The Moonlight of Seoul
# 23  22427              섹스 위드 러브                            Sex with Love
# 24  22738              나고야 살인사건                     A Slit-Mouthed Woman
# 25  22788                보딩 게이트                            Boarding Gate
# 26  23157                황혼의 댄서                         Twilight Dancers
# 27  24188                드라마/멕스                                Drama/Mex
# 28  39785                    허풍                                The Bluff
# 29  40892  네 몸에서 흐르는 눈물의 이상한 색깔  The Strange Colour of Your Body’s Tears
# 30  41430                   플러쉬                                    Plush
# 31  60789            거룩한 술꾼의 전설           The Legend Of The Holy Drinker
#
#     year        country     grade   genre  runtime release_date  audience  \
# 0   1994             미국  청소년 관람불가      범죄       90   1994-10-19    1019.0
# 1   2000             미국  청소년 관람불가  멜로·로맨스       95   1994-10-29    1882.0
# 2   1995             미국  청소년 관람불가      범죄      101   1997-09-27     712.0
# 3   1992             미국  청소년 관람불가      공포      115   1993-10-30    1984.0
# 4   1992             미국  청소년 관람불가      범죄       82   1992-08-01    9768.0
# 5   1992           이탈리아  청소년 관람불가      범죄       87   1993-08-20    6043.0
# 6   1985            프랑스  청소년 관람불가     드라마       82   1993-07-24    1678.0
# 7   1992             미국  청소년 관람불가      범죄       90   1993-04-22    4210.0
# 8   1999   프랑스,이탈리아,터어키  청소년 관람불가     드라마      108         None       NaN
# 9   1990        이탈리아,영국  청소년 관람불가     드라마      107         None       NaN
# 10  1992             일본  청소년 관람불가     드라마      106   2005-12-02    2533.0
# 11  1980         독일,스웨덴  청소년 관람불가     드라마      104         None       NaN
# 12  1996       프랑스,이탈리아  청소년 관람불가     드라마       98   2004-09-10       NaN
# 13  2005            프랑스  청소년 관람불가     코미디      100         None       NaN
# 14  2006             한국  청소년 관람불가  멜로·로맨스      114   2006-11-16   43348.0
# 15  2000             일본  청소년 관람불가     드라마      114   2006-07-14      30.0
# 16  2005       콜롬비아,스페인  청소년 관람불가      범죄      105   2006-08-31       NaN
# 17  2005             일본  청소년 관람불가     드라마      109         None       NaN
# 18  2007             일본  청소년 관람불가     드라마      125   2007-11-22     331.0
# 19  2006             미국  청소년 관람불가     드라마      136   2007-02-15    1501.0
# 20  2005            필리핀  청소년 관람불가     드라마      116         None       NaN
# 21  2006     벨기에,프랑스,영국  청소년 관람불가     드라마      130   2007-07-11   14932.0
# 22  2007             한국  청소년 관람불가     드라마      123   2008-04-30  727409.0
# 23  2003             칠레  청소년 관람불가     코미디       90         None       NaN
# 24  2007             일본  청소년 관람불가      공포       90   2007-08-09     124.0
# 25  2007            프랑스  청소년 관람불가      범죄      118   2008-02-21      79.0
# 26  2006            필리핀  청소년 관람불가     드라마      105         None       NaN
# 27  2006            멕시코  청소년 관람불가     드라마       93   2008-01-24       NaN
# 28  2013             한국  청소년 관람불가     드라마       77         None       NaN
# 29  2013  프랑스,벨기에,룩셈부르크  청소년 관람불가     스릴러      102         None       NaN
# 30  2013             미국  청소년 관람불가     스릴러       99   2014-03-27       1.0
# 31  1988       프랑스,이탈리아  15세이상관람가     드라마      128   2023-08-30    1807.0
#
#               director                                              story  \
# 0              로렌스 레노프  카린 스완은 젊고 아름다운 사진작가로 스튜디오를 경영하고 있다. 촬영차 인도에 다녀...
# 1              나단 스티븐스  성공한 사업가 다니엘 데이비스의 아내 모이라는 돈과 지위 무엇 하나 부러울 게 없는...
# 2               조지 케이스  유능한 변호사 개빈은 자동차 접촉 사고로 우연히 도라라는 여자를 만난다. 접촉사고는...
# 3              클레이 보리스  1957년, '무도회의 여왕' 파티가 개최되고 있는 해밀튼 고교. 닉과 리사는 파트...
# 4            에이미 골드스타인  여자 킬러로 명성을 날리던 안젤리카는 평온한 삶을 살기 위해 킬러로서의 생활을 청산...
# 5            세르지오 마르티노  전직 경관 마크 데릭은 암흑조직과 거래했다가 배신한 댓가로 경찰에서 파면되고 아내와...
# 6              앙드레 테시네  부동산회사에 근무하는 순진한 청년 폴로는 갈데가 없다는 여배우 니나를 자신의 아파트...
# 7               테리 트리스  잭과 크릭은 새 파트너가 되어 정사도중 남자를 총을 쏴 살해한 일명 라푼젤 사건을 ...
# 8             페르잔 오즈페텍  어느날, 황제의 화실에 불이 난다. 그 사건은 황제의 관심에서 멀어질까봐 두려워한 ...
# 9               폴 슈레이더  영국인 커플 콜린과 메리는 그들의 관계를 지속할 것인지 결정짓기 위해 휴가를 이용하...
# 10              무라카미 류  빛나는 도시의 밤. 초호화 스위트룸... 외로운 사람들이 나를 기다린다 빛나는 도시...
# 11             잉마르 베리만  전문직 커플인 카타리나와 페터 부부는 아이가 없고, 사이가 좋지 않다. 첫 장면에서...
# 12  파올로 타비아니 비토리오 타비아니  카를로타와 에도아르도는 20년만에 만나 결혼한다. 에도아르도의 영지에 정착한 후 친...
# 13            앙토니 코르디에  프랑스의 작은 마을에 사는 십대들의 고뇌를 잘 표현하고 있는 이 영화는 사랑과 섹스...
# 14                이송희일  나도 이유를 모르겠어! 그냥 니가 좋아... 삭막한 도시, 두 청춘의 피할 수 없는...
# 15            이시오카 마사토  17살인 마리와 아츠시는 연인 사이다. 둘은 집을 가출해 함께 살기 위해 도쿄로 온...
# 16           세르지오 카브레라  난자된 시체를 둘러싼 에로틱한 거래와 충격적인 음모….. 신문 기자인 빅터 실람파는...
# 17              호리에 케이  우리들의 ‘추억’은 거짓말투성이다 잊었다고 생각했다 하지만 7년만의 재회는 모든 침...
# 18            츠루하시 야스오  모두가 숨 죽인 격정적인 사랑이 온다 내 인생에서 오늘이 최고로 행복한 날이에요. ...
# 19               토드 필드  내 인생에 찾아온 아릿한 도발 우리… 사랑일까? 내 인생에 찾아온 아릿한 도발, 우...
# 20     엘렌 라모스 파올로 비야루나  1958년, 젊은 청년 미겔은 현대화가인 아버지가 있는 마닐라를 방문하지만, 아버지...
# 21              파스칼 페랭  ...사랑하고 싶다. 1917년, 광산을 운영하는 클리포드와 결혼한 콘스탄스. 하지...
# 22                 윤종빈  우리의 밤은 당신의 낮보다 화려하다! 하루를 살아도 느낌있게 살고 싶은 호스트들의 ...
# 23             보리스 퀘시아  섹시한 유머의 진수, 웰메이드 섹스 코미디 고등학교 자녀를 둔 학부모들이 학교에서 ...
# 24             시라이시 코지  나처럼 만들어줄까? 모든 것은 그곳에서 시작되었다.  “하얀 마스크를 쓴 여자가 아...
# 25           올리비에 아사야스  살인, 음모, 배신 그리고 비즈니스…… 그 모든 게 사랑에서 시작됐다  런던, 홍콩...
# 26              멜 치옹글로  세 명의 마초 댄서들을 통해 필리핀 사회의 진실을 보여주는 영화. 보기에 따라서는 ...
# 27             헤랄도 나라뇨  ‘이투마마’ 그후 또 다른 멕시코식 유혹… 페르난다는 자신을 떠난 전 남자친구인 차...
# 28                 공자관  간만에 모인 친구 4인방. 언제나 그렇듯이 별 볼일 없는 대화와 이어지는 음담패설들...
# 29      헬렌 카테 브루노 포르자니  해외출장에서 돌아와 아내가 실종된 것을 발견한 한 회사원이 수소문에 나선다. 그러나...
# 30             캐서린 하드윅  음악을 향한 비틀린 만남, 광기 어린 사랑을 낳다!  인기 록밴드 ‘플러쉬’의 보컬...
# 31             에르만노 올미  파리 센 강의 다리 밑에서 알코올에 찌든 채 하루하루를 보내는 노숙자 안드레아스(룻...
#
#                                           poster_link
# 0   https://image.cine21.com/resize/www1/common/co...
# 1   https://image.cine21.com/resize/www1/common/co...
# 2   https://image.cine21.com/resize/www1/common/co...
# 3   https://image.cine21.com/resize/www1/common/co...
# 4   https://image.cine21.com/resize/www1/common/co...
# 5   https://image.cine21.com/resize/www1/common/co...
# 6   https://image.cine21.com/resize/www1/common/co...
# 7   https://image.cine21.com/resize/www1/common/co...
# 8   https://image.cine21.com/resize/www1/common/co...
# 9   https://image.cine21.com/resize/www1/common/co...
# 10  https://image.cine21.com/resize/www1/common/co...
# 11  https://image.cine21.com/resize/www1/common/co...
# 12  https://image.cine21.com/resize/www1/common/co...
# 13  https://image.cine21.com/resize/www1/common/co...
# 14  https://image.cine21.com/resize/www1/common/co...
# 15  https://image.cine21.com/resize/www1/common/co...
# 16  https://image.cine21.com/resize/www1/common/co...
# 17  https://image.cine21.com/resize/www1/common/co...
# 18  https://image.cine21.com/resize/www1/common/co...
# 19  https://image.cine21.com/resize/www1/common/co...
# 20  https://image.cine21.com/resize/www1/common/co...
# 21  https://image.cine21.com/resize/www1/common/co...
# 22  https://image.cine21.com/resize/www1/common/co...
# 23  https://image.cine21.com/resize/www1/common/co...
# 24  https://image.cine21.com/resize/www1/common/co...
# 25  https://image.cine21.com/resize/www1/common/co...
# 26  https://image.cine21.com/resize/www1/common/co...
# 27  https://image.cine21.com/resize/www1/common/co...
# 28  https://image.cine21.com/resize/www1/common/co...
# 29  https://image.cine21.com/resize/www1/common/co...
# 30  https://image.cine21.com/resize/www1/common/co...
# 31  https://image.cine21.com/resize/www1/common/co...

# %%
conn = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'signcity114',
    database = 'MyDB'
)

cursor = conn.cursor()

query = """
SELECT * FROM movie
where genre not like '%, %'
and (genre is not null)
and (poster_link is not null)
and (genre not like '%실험영화%')
and (genre not like '%무성 영화%')
and (genre not like '%단편 영화%')
and (genre not like '%흑백 영화%')
and (poster_link != 'https://image.cine21.com/resize/www1/common/content19_1[X230,330].jpg');"""

df = pd.read_sql(query, conn)
df
# Out:
# /var/folders/ld/7fj1069x6q7fr5894rwywdk40000gn/T/ipykernel_29246/202215299.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#           id                 ko_name                         en_name    year  \
# 0          7  아기공룡 둘리: 얼음별 대모험 리마스터링          Little Dinosaur Doolie  1996.0
# 1         11                 마이클 콜린스                 Michael Collins  1996.0
# 2         12                  트레인스포팅                   Trainspotting  1996.0
# 3         15                    동궁서궁         East Palace West Palace  1996.0
# 4         18             시간은 오래 지속된다                      Time Lasts  1996.0
# ...      ...                     ...                             ...     ...
# 14899  61814                    모든 점                Every Single Dot  2024.0
# 14900  61816        정국: 아이 엠 스틸 위드 유  JUNG KOOK: I AM STILL with you  2024.0
# 14901  61820                  4분 44초                                  2022.0
# 14902  61824               춘천대첩 72시간                                  2024.0
# 14903  61826                    허 바디                        Her body  2023.0
#
#           country     grade  genre  runtime release_date  audience  \
# 0              한국    전체 관람가  애니메이션     84.0   2023-05-24  126874.0
# 1      영국,아일랜드,미국  15세이상관람가    드라마    132.0   1997-01-18   33719.0
# 2              영국  청소년 관람불가    드라마     91.0   1997-02-22  139322.0
# 3              중국  청소년 관람불가    드라마     90.0         None       NaN
# 4              한국  15세이상관람가    드라마     90.0         None       NaN
# ...           ...       ...    ...      ...          ...       ...
# 14899          한국      None  다큐멘터리     83.0         None       NaN
# 14900          한국    전체 관람가     뮤직    111.0   2024-10-09    5849.0
# 14901          한국  12세이상관람가     공포     44.0   2024-11-01       NaN
# 14902          한국    전체 관람가  다큐멘터리     94.0   2024-11-14       NaN
# 14903          체코  청소년 관람불가    드라마    106.0   2024-10-31       NaN
#
#          director                                              story  \
# 0         김수정 임경원  아기공룡 둘리는 1억 년 전 거대한 빙산 조각에 갇혀 엄마와 헤어지게 되고 그 안에...
# 1            닐 조던  12세기 이래로 영국의 통치를 받아 온 아일랜드의 독립군은 6개월간의 투쟁 끝에 영...
# 2           대니 보일  마크 렌턴은 에딘버러의 거리에서 두 명의 상점 감시자들에게 쫓기고 있다. 자켓에 넣...
# 3             장유안  민감한 젊은 작가 아란은 어느날 동성애자들이 종종 찾는 북경의 국립공원을 거닐고 있...
# 4             김응수  하얗게 눈이 쌓인 모스크바 근교의 별장. 새해를 앞두고 한무리의 한국인들이 모인다....
# ...           ...                                                ...
# 14899         이소정  어느 날 ‘그’가 ‘나’에게 필름을 보내왔다. 그는 나에게 오랜 기간 여행하며 찍은...
# 14900        None                                         줄거리가 없습니다.
# 14901         박종균  [입주민 여러분께 협조 요청 드립니다] 북촌아파트 경비실입니다. 최근 우리 단지 내...
# 14902     장이레 최동호  반드시 기억해야 할 승리가 온다! 역사에는 가정이 없다고 하지만 만약 그날 춘천에서...
# 14903  나탈리 키사로브스카  “숨겨진 욕망, 또 하나의 격렬한 스포츠” 올림픽 메달을 노리던 프로다이버 안드레아...
#
#                                              poster_link
# 0      https://image.cine21.com/resize/cine21/poster/...
# 1      https://image.cine21.com/resize/cine21/poster/...
# 2      https://image.cine21.com/resize/IMGDB/poster/2...
# 3      https://image.cine21.com/resize/cine21/poster/...
# 4      https://image.cine21.com/resize/cine21/poster/...
# ...                                                  ...
# 14899  https://image.cine21.com/resize/cine21/poster/...
# 14900  https://image.cine21.com/resize/cine21/poster/...
# 14901  https://image.cine21.com/resize/cine21/poster/...
# 14902  https://image.cine21.com/resize/cine21/poster/...
# 14903  https://image.cine21.com/resize/cine21/poster/...
#
# [14904 rows x 13 columns]

# %%
conn = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'signcity114',
    database = 'MyDB'
)

cursor = conn.cursor()

query = """
SELECT * FROM movie
where genre not like '%, %'
and (genre is not null)
and (poster_link is not null)
and (genre not like '%실험영화%')
and (genre not like '%무성 영화%')
and (genre not like '%단편 영화%')
and (genre not like '%흑백 영화%');"""

df = pd.read_sql(query, conn)
df

# %%
df['genre'].value_counts(ascending=True)
# Out:
# genre
# 실화           1
# 서스펜스         2
# 3D           3
# 역사·서사        3
# 전기           3
# 스포츠          4
# 블록버스터       11
# 어드벤처        14
# 느와르         17
# 시대극         17
# 옴니버스        23
# 무협          33
# 전쟁          33
# 가족          40
# 뮤지컬         64
# 미스터리        67
# 서부          69
# 판타지         72
# 뮤직         111
# SF         148
# 범죄         461
# 스릴러        504
# 멜로·로맨스     606
# 공포         645
# 액션         944
# 애니메이션      994
# 다큐멘터리     1609
# 코미디       1720
# 드라마       6686
# Name: count, dtype: int64

# %%
genre_dict = {'범죄' : '범죄,스릴러,서스펜스', '스릴러' : '범죄,스릴러,서스펜스', '서스펜스' : '범죄,스릴러,서스펜스',
              '멜로·로맨스' : '멜로·로맨스,드라마', '드라마' : '멜로·로맨스,드라마',
              '액션' : '액션,어드벤처,판타지,SF', '어드벤처' : '액션,어드벤처,판타지,SF',
              '판타지' : '액션,어드벤처,판타지,SF', 'SF' : '액션,어드벤처,판타지,SF',
              '공포' : '공포,미스터리', '미스터리' : '공포,미스터리',
              '뮤지컬' : '뮤지컬,뮤직', '뮤직' : '뮤지컬,뮤직',
              '전쟁' : '전쟁,역사·서사,시대극', '역사·서사' : '전쟁,역사·서사,시대극',
              '시대극' : '전쟁,역사·서사,시대극'}

df['genre'] = df['genre'].apply(lambda x : genre_dict[x])

# %%
df['genre'].value_counts(ascending=True)
# Out:
# genre
# 실화                   1
# 3D                   3
# 전기                   3
# 스포츠                  4
# 블록버스터               11
# 느와르                 17
# 옴니버스                23
# 무협                  33
# 가족                  40
# 전쟁,역사·서사,시대극        53
# 서부                  69
# 뮤지컬,뮤직             175
# 공포,미스터리            712
# 범죄,스릴러,서스펜스        967
# 애니메이션              994
# 액션,어드벤처,판타지,SF    1178
# 다큐멘터리             1609
# 코미디               1720
# 멜로·로맨스,드라마        7292
# Name: count, dtype: int64

# %%
low_count_threshold = 200
df['genre'] = df['genre'].apply(lambda x: '기타' if df['genre'].value_counts()[x] < low_count_threshold else x)

# %%
# 경로 생성
movie_path = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
for i in df['genre'].value_counts().index:
    if os.path.exists(os.path.join(movie_path, i)) == False:
        os.mkdir(os.path.join(movie_path, i))

# %%
value = df['genre'].value_counts()
plt.rc('font', family='AppleGothic')
plt.pie(value, labels=value.index, autopct='%.1f%%')
plt.title('영화 장르')
plt.show()

# %%
# # 포스터 저장
# idx = 6208
# poster_link = df['poster_link'][idx:]
# for index, link in enumerate(poster_link):
#     response = requests.get(link)
#     img = Image.open(BytesIO(response.content))
#     RGB_img = img.convert('RGB')
#     id = df['id'][index+idx]
#     RGB_img.save(f"/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터/{df['genre'][idx+index]}/{id}.jpg")
#     print(f"{idx+index} 이미지 저장 완료")

# %%
# Out:
# genre
# 멜로·로맨스,드라마        7292
# 코미디               1720
# 다큐멘터리             1609
# 액션,어드벤처,판타지,SF    1178
# 애니메이션              994
# 범죄,스릴러,서스펜스        967
# 공포,미스터리            712
# Name: count, dtype: int64

# %%
label_index = ['멜로·로맨스,드라마', '코미디', '다큐멘터리', '애니메이션', '범죄,스릴러,서스펜스', '공포,미스터리', '액션,어드벤처,판타지,SF']
plt.pie(value.iloc[:-1].values, labels=value.iloc[:-1].index, autopct='%1.1f%%')
plt.show()

# %%
def image_augment(genre_name, image_path, flip = False, elastic = False, color = False,
                  flip_elastic = False, flip_color = False, elastic_color = False):
    elastic_transform = transforms.ElasticTransform()
    flip_transform = transforms.RandomHorizontalFlip(p=1)
    color_jitter = transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2)
    # brightness : 밝기, contrast : 대비, saturation : 채도, hue : 색조
    for i in df[df['genre'] == genre_name]['id']:
        image = Image.open(os.path.join(image_path, genre_name, f"{i}.jpg"))
        # 반전
        flip_image = flip_transform(image)
        # 왜곡
        elastic_image = elastic_transform(image)
        # 색상
        color_jitter_image = color_jitter(image)
        # 반전_색상
        flip_color_jitter_image = color_jitter(flip_image)
        # 반전_왜곡
        flip_elastic_image = elastic_transform(flip_image)
        # 왜곡_색상
        elastic_color_jitter_image = color_jitter(elastic_image)
        if flip == True:
            flip_image.save(os.path.join(image_path, genre_name, f"{i}_flip.jpg"))
        if elastic == True:
            elastic_image.save(os.path.join(image_path, genre_name, f"{i}_elastic.jpg"))
        if color == True:
            color_jitter_image.save(os.path.join(image_path, genre_name, f"{i}_color_jitter.jpg"))
        if flip_elastic == True:
            flip_elastic_image.save(os.path.join(image_path, genre_name, f"{i}_flip_elastic.jpg"))
        if flip_color == True:
            flip_color_jitter_image.save(os.path.join(image_path, genre_name, f"{i}_flip_color_jitter.jpg"))
        if elastic_color == True:
            elastic_color_jitter_image.save(os.path.join(image_path, genre_name, f"{i}_elastic_color_jitter.jpg"))

# %%
# # 코미디 4배 증강
# GENRE_NAME = '코미디'
# IMAGE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
# image_augment(GENRE_NAME, IMAGE_PATH, elastic=True, flip_color=True, flip_elastic=True)

# # 다큐멘터리 4배 증강
# GENRE_NAME = '다큐멘터리'
# IMAGE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
# image_augment(GENRE_NAME, IMAGE_PATH, elastic=True, flip_color=True, flip_elastic=True)

# # 액션,어드벤처,판타지,SF 6배 증강
# GENRE_NAME = '액션,어드벤처,판타지,SF'
# IMAGE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
# image_augment(GENRE_NAME, IMAGE_PATH, elastic=True, flip_color=True, flip_elastic=True,
#               elastic_color=True, flip=True)

# # 애니메이션 6배 증강
# GENRE_NAME = '애니메이션'
# IMAGE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
# image_augment(GENRE_NAME, IMAGE_PATH, elastic=True, color=True,
#               flip_color=True, flip_elastic=True, elastic_color=True)

# # 범죄,스릴러,서스펜스 6배 증강
# GENRE_NAME = '범죄,스릴러,서스펜스'
# IMAGE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
# image_augment(GENRE_NAME, IMAGE_PATH, elastic=True, color=True,
#               flip_color=True, flip_elastic=True, elastic_color=True)

# # 공포,미스터리 7배 증강
# GENRE_NAME = '공포,미스터리'
# IMAGE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터'
# image_augment(GENRE_NAME, IMAGE_PATH, flip=True, elastic=True, color=True,
#               flip_color=True, flip_elastic=True, elastic_color=True)

# %%
# 이미지 전처리(transform) 정의
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 이미지 크기 조정
    transforms.ToTensor(),          # 텐서로 변환
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # ImageNet 정규화 값
])

DS = datasets.ImageFolder(root='/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/영화 포스터', transform=transform)
print(DS.classes)
# Out:
# ['애니메이션', '액션,어드벤처,판타지,SF', '공포,미스터리', '다큐멘터리', '멜로·로맨스,드라마', '범죄,스릴러,서스펜스', '코미디']

# %%
image_path = [i[0] for i in DS.samples]
labels = [i[1] for i in DS.samples]
targets = [DS.classes[i[1]] for i in DS.samples]

# %%
augment_value = pd.Series(targets).value_counts()
augment_value
# Out:
# 멜로·로맨스,드라마                     7293
# 코미디                            6880
# 다큐멘터리                          6436
# 애니메이션                    5964
# 범죄,스릴러,서스펜스                    5802
# 공포,미스터리                        4984
# 액션,어드벤처,판타지,SF    4712
# Name: count, dtype: int64

# %%
label_index = ['멜로·로맨스,드라마', '코미디', '다큐멘터리', '애니메이션', '범죄,스릴러,서스펜스', '공포,미스터리', '액션,어드벤처,판타지,SF']
plt.pie(augment_value.values, labels=label_index, autopct='%1.1f%%')
plt.show()

# %%
train_path, test_path, train_label, test_label = train_test_split(image_path, labels, train_size=0.8,
                                                                  stratify=labels, random_state=42)
train_path, valid_path, train_label, valid_label = train_test_split(train_path, train_label, train_size=0.8,
                                                                    stratify=train_label, random_state=42)

# %%
class CustomImageDataset(Dataset):
    def __init__(self, image_paths, labelsDF, transform=None):
        super().__init__()
        self.image_paths = image_paths
        self.labels = np.array(labelsDF)
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path)
        label = self.labels[idx]

        if self.transform:
            input_tensor = self.transform(image)

        label_tensor = torch.tensor(label, dtype=torch.float)

        return input_tensor, label_tensor

# %%
trainDS = CustomImageDataset(train_path, train_label, transform)
validDS = CustomImageDataset(valid_path, valid_label, transform)
testDS = CustomImageDataset(test_path, test_label, transform)

trainDL = DataLoader(trainDS, batch_size=32, shuffle=True)
validDL = DataLoader(validDS, batch_size=32, shuffle=True)
testDL = DataLoader(testDS, batch_size=32, shuffle=True)

# %%
plt.imshow(trainDL.dataset[1][0].permute(1,2,0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 미리 학습된 ResNet 모델 불러오기 (weight 사용)
model = models.resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)

# 합성곱층 가중치 고정
for param in model.parameters():
    param.requires_grad = False

# 전결합층 가중치 변경하도록 설정
for param in model.fc.parameters():
    param.requires_grad = True

# 마지막 레이어 (full connected layer) 교체
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, 8))

# %%
# 마지막 레이어 (full connected layer) 교체
# num_features = model.fc.in_features # 2048
# model.fc = nn.Linear(num_features, 8)

# %%
# MPS 사용 여부 확인하기
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"device : {device}")
# Out:
# device : mps

# %%
# 훈련
EPOCH = 100
SAVE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/ResNet50'

# 옵티마이저를 모델 파라미터에 대해 초기화
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# optimizer = torch.optim.RAdam(model.parameters(), lr=0.005)


result = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
                  endurance_cnt = 10, view_epoch = 1, num_classes = 8, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
# Out:
# [EPOCH] : 1에서 모델 저장 완료.
# [Loss : 1/100] Train : 1.5014, Test : 1.3095
# [Score  : 1/100] Train : 0.4428, Test : 0.5298
# [EPOCH] : 2에서 모델 저장 완료.
# [Loss : 2/100] Train : 1.2368, Test : 1.2813
# [Score  : 2/100] Train : 0.5481, Test : 0.5308
# [EPOCH] : 3에서 모델 저장 완료.
# [Loss : 3/100] Train : 1.1695, Test : 1.1937
# [Score  : 3/100] Train : 0.5714, Test : 0.5680
# [EPOCH] : 4에서 모델 저장 완료.
# [Loss : 4/100] Train : 1.1110, Test : 1.1815
# [Score  : 4/100] Train : 0.5907, Test : 0.5754
# [Loss : 5/100] Train : 1.0599, Test : 1.1971
# [Score  : 5/100] Train : 0.6110, Test : 0.5623
# [EPOCH] : 6에서 모델 저장 완료.
# [Loss : 6/100] Train : 1.0215, Test : 1.1372
# [Score  : 6/100] Train : 0.6279, Test : 0.5895
# [EPOCH] : 7에서 모델 저장 완료.
# [Loss : 7/100] Train : 0.9639, Test : 1.1238
# [Score  : 7/100] Train : 0.6495, Test : 0.5873
# [Loss : 8/100] Train : 0.9147, Test : 1.1891
# [Score  : 8/100] Train : 0.6675, Test : 0.5684
# [EPOCH] : 9에서 모델 저장 완료.
# [Loss : 9/100] Train : 0.8635, Test : 1.1045
# [Score  : 9/100] Train : 0.6843, Test : 0.6002
# [Loss : 10/100] Train : 0.8178, Test : 1.1128
# [Score  : 10/100] Train : 0.6991, Test : 0.6160
# [Loss : 11/100] Train : 0.7831, Test : 1.1137
# [Score  : 11/100] Train : 0.7146, Test : 0.6078
# [EPOCH] : 12에서 모델 저장 완료.
# [Loss : 12/100] Train : 0.7329, Test : 1.0823
# [Score  : 12/100] Train : 0.7333, Test : 0.6320
# [EPOCH] : 13에서 모델 저장 완료.
# [Loss : 13/100] Train : 0.6906, Test : 1.0453
# [Score  : 13/100] Train : 0.7512, Test : 0.6392
# [Loss : 14/100] Train : 0.6530, Test : 1.0858
# [Score  : 14/100] Train : 0.7625, Test : 0.6257
# [Loss : 15/100] Train : 0.6443, Test : 1.1528
# [Score  : 15/100] Train : 0.7652, Test : 0.6143
# [Loss : 16/100] Train : 0.6585, Test : 1.0740
# [Score  : 16/100] Train : 0.7605, Test : 0.6431
# [Loss : 17/100] Train : 0.5810, Test : 1.0830
# [Score  : 17/100] Train : 0.7894, Test : 0.6486
# [Loss : 18/100] Train : 0.5480, Test : 1.0920
# [Score  : 18/100] Train : 0.8005, Test : 0.6396
# [Loss : 19/100] Train : 0.5275, Test : 1.1413
# [Score  : 19/100] Train : 0.8083, Test : 0.6381
# [Loss : 20/100] Train : 0.5015, Test : 1.1632
# [Score  : 20/100] Train : 0.8163, Test : 0.6282
# [Loss : 21/100] Train : 0.4709, Test : 1.1102
# [Score  : 21/100] Train : 0.8293, Test : 0.6520
# [Loss : 22/100] Train : 0.4528, Test : 1.2061
# [Score  : 22/100] Train : 0.8352, Test : 0.6396
# [Loss]값의 개선이 이루어지지 않아 [23] EPOCH에서 학습을 종료합니다.

# %%
DrawPlot(result)
plt.show()

# %%
# 미리 학습된 ResNet 모델 불러오기 (weight 사용)
model = models.resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)

# 합성곱층 가중치 고정
for param in model.parameters():
    param.requires_grad = False

# 전결합층 가중치 변경하도록 설정
for param in model.fc.parameters():
    param.requires_grad = True

# 마지막 레이어 (full connected layer) 교체
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, 7))

# %%
# 훈련
EPOCH = 100
SAVE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/ResNet50'

# 옵티마이저를 모델 파라미터에 대해 초기화
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

optimizer = torch.optim.RAdam(model.parameters(), lr=0.001)


result = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
                  endurance_cnt = 10, view_epoch = 1, num_classes = 7, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
# Out:
# [EPOCH] : 1에서 모델 저장 완료.
# [Loss : 1/100] Train : 1.4459, Test : 1.2630
# [Score  : 1/100] Train : 0.4527, Test : 0.5243
# [EPOCH] : 2에서 모델 저장 완료.
# [Loss : 2/100] Train : 1.2133, Test : 1.2294
# [Score  : 2/100] Train : 0.5478, Test : 0.5442
# [Loss : 3/100] Train : 1.1457, Test : 1.2589
# [Score  : 3/100] Train : 0.5718, Test : 0.5258
# [EPOCH] : 4에서 모델 저장 완료.
# [Loss : 4/100] Train : 1.0911, Test : 1.0958
# [Score  : 4/100] Train : 0.5927, Test : 0.5944
# [Loss : 5/100] Train : 1.0345, Test : 1.1424
# [Score  : 5/100] Train : 0.6150, Test : 0.5783
# [EPOCH] : 6에서 모델 저장 완료.
# [Loss : 6/100] Train : 0.9805, Test : 1.0697
# [Score  : 6/100] Train : 0.6297, Test : 0.5981
# [Loss : 7/100] Train : 0.9144, Test : 1.0717
# [Score  : 7/100] Train : 0.6577, Test : 0.6008
# [EPOCH] : 8에서 모델 저장 완료.
# [Loss : 8/100] Train : 0.8470, Test : 1.0377
# [Score  : 8/100] Train : 0.6841, Test : 0.6194
# [EPOCH] : 9에서 모델 저장 완료.
# [Loss : 9/100] Train : 0.7812, Test : 1.0149
# [Score  : 9/100] Train : 0.7090, Test : 0.6260
# [EPOCH] : 10에서 모델 저장 완료.
# [Loss : 10/100] Train : 0.7198, Test : 0.9847
# [Score  : 10/100] Train : 0.7313, Test : 0.6473
# [EPOCH] : 11에서 모델 저장 완료.
# [Loss : 11/100] Train : 0.6516, Test : 0.9672
# [Score  : 11/100] Train : 0.7568, Test : 0.6469
# [EPOCH] : 12에서 모델 저장 완료.
# [Loss : 12/100] Train : 0.6077, Test : 0.9346
# [Score  : 12/100] Train : 0.7730, Test : 0.6691
# [Loss : 13/100] Train : 0.5425, Test : 1.0248
# [Score  : 13/100] Train : 0.7978, Test : 0.6473
# [Loss : 14/100] Train : 0.4959, Test : 1.0054
# [Score  : 14/100] Train : 0.8148, Test : 0.6529
# [Loss : 15/100] Train : 0.4604, Test : 1.0310
# [Score  : 15/100] Train : 0.8293, Test : 0.6662
# [Loss : 16/100] Train : 0.4042, Test : 1.0433
# [Score  : 16/100] Train : 0.8502, Test : 0.6805
# [Loss : 17/100] Train : 0.3749, Test : 1.0982
# [Score  : 17/100] Train : 0.8614, Test : 0.6712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 11
#       5 # 옵티마이저를 모델 파라미터에 대해 초기화
#       6 # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#       8 optimizer = torch.optim.RAdam(model.parameters(), lr=0.001)
# ---> 11 result = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
#      12                   endurance_cnt = 10, view_epoch = 1, num_classes = 7, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
#
# File ~/WorkSpace/KDT2/MyModule/KDTModule.py:311, in training(train_DataLoader, test_DataLoader, model, model_type, optimizer, epoch, endurance_cnt, view_epoch, num_classes, SAVE_PATH, MPS, device)
#     308 total_loss_train = 0 # 한 에포크당 합산할 손실값 (나중에 평균 계산)
#     309 total_score_train = 0 # 한 에포크당 합산할 손실값 (나중에 평균 계산)
# --> 311 for X_batch, y_batch in train_DataLoader:
#     312     if MPS:
#     313         model.to(device)  # 모델을 MPS 장치로 이동
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[23], line 17, in CustomImageDataset.__getitem__(self, idx)
#      14 label = self.labels[idx]
#      16 if self.transform:
# ---> 17     input_tensor = self.transform(image)
#      19 label_tensor = torch.tensor(label, dtype=torch.float)
#      21 return input_tensor, label_tensor
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/functional.py:174, in to_tensor(pic)
#     172 img = img.view(pic.size[1], pic.size[0], F_pil.get_image_num_channels(pic))
#     173 # put it from HWC to CHW format
# --> 174 img = img.permute((2, 0, 1)).contiguous()
#     175 if isinstance(img, torch.ByteTensor):
#     176     return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %%
# 미리 학습된 ResNet 모델 불러오기 (weight 사용)
model = models.resnet50(weights=ResNet50_Weights.IMAGENET1K_V1)

# 합성곱층 가중치 고정
for param in model.parameters():
    param.requires_grad = False

# 전결합층 가중치 변경하도록 설정
for param in model.fc.parameters():
    param.requires_grad = True

# 마지막 레이어 (full connected layer) 교체
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 1024),
    nn.ReLU(),
    nn.Linear(1024, 128),
    nn.ReLU(),
    nn.Linear(128, 7))

# %%
# 훈련
EPOCH = 100
SAVE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/ResNet50'

# 옵티마이저를 모델 파라미터에 대해 초기화
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

optimizer = torch.optim.RAdam(model.parameters(), lr=0.001)


result = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
                  endurance_cnt = 10, view_epoch = 1, num_classes = 7, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
# Out:
# [EPOCH] : 1에서 모델 저장 완료.
# [Loss : 1/100] Train : 1.3976, Test : 1.2739
# [Score  : 1/100] Train : 0.4707, Test : 0.5328
# [EPOCH] : 2에서 모델 저장 완료.
# [Loss : 2/100] Train : 1.2150, Test : 1.2015
# [Score  : 2/100] Train : 0.5443, Test : 0.5584
# [EPOCH] : 3에서 모델 저장 완료.
# [Loss : 3/100] Train : 1.1512, Test : 1.1997
# [Score  : 3/100] Train : 0.5694, Test : 0.5494
# [EPOCH] : 4에서 모델 저장 완료.
# [Loss : 4/100] Train : 1.0862, Test : 1.1438
# [Score  : 4/100] Train : 0.5929, Test : 0.5686
# [EPOCH] : 5에서 모델 저장 완료.
# [Loss : 5/100] Train : 1.0328, Test : 1.0819
# [Score  : 5/100] Train : 0.6124, Test : 0.5945
# [EPOCH] : 6에서 모델 저장 완료.
# [Loss : 6/100] Train : 0.9720, Test : 1.0405
# [Score  : 6/100] Train : 0.6362, Test : 0.6131
# [Loss : 7/100] Train : 0.9030, Test : 1.0808
# [Score  : 7/100] Train : 0.6591, Test : 0.6091
# [EPOCH] : 8에서 모델 저장 완료.
# [Loss : 8/100] Train : 0.8284, Test : 1.0083
# [Score  : 8/100] Train : 0.6910, Test : 0.6328
# [Loss : 9/100] Train : 0.7518, Test : 1.0223
# [Score  : 9/100] Train : 0.7189, Test : 0.6351
# [EPOCH] : 10에서 모델 저장 완료.
# [Loss : 10/100] Train : 0.6819, Test : 0.9855
# [Score  : 10/100] Train : 0.7462, Test : 0.6443
# [Loss : 11/100] Train : 0.6297, Test : 1.0774
# [Score  : 11/100] Train : 0.7602, Test : 0.6396
# [EPOCH] : 12에서 모델 저장 완료.
# [Loss : 12/100] Train : 0.5617, Test : 0.9769
# [Score  : 12/100] Train : 0.7893, Test : 0.6650
# [Loss : 13/100] Train : 0.5013, Test : 0.9977
# [Score  : 13/100] Train : 0.8116, Test : 0.6575
# [Loss : 14/100] Train : 0.4528, Test : 1.0143
# [Score  : 14/100] Train : 0.8284, Test : 0.6715
# [Loss : 15/100] Train : 0.4100, Test : 1.0095
# [Score  : 15/100] Train : 0.8486, Test : 0.6828
# [Loss : 16/100] Train : 0.3612, Test : 1.1470
# [Score  : 16/100] Train : 0.8647, Test : 0.6678
# [Loss : 17/100] Train : 0.3346, Test : 1.0825
# [Score  : 17/100] Train : 0.8754, Test : 0.6858
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 11
#       5 # 옵티마이저를 모델 파라미터에 대해 초기화
#       6 # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#       8 optimizer = torch.optim.RAdam(model.parameters(), lr=0.001)
# ---> 11 result = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
#      12                   endurance_cnt = 10, view_epoch = 1, num_classes = 7, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
#
# File ~/WorkSpace/KDT2/MyModule/KDTModule.py:311, in training(train_DataLoader, test_DataLoader, model, model_type, optimizer, epoch, endurance_cnt, view_epoch, num_classes, SAVE_PATH, MPS, device)
#     308 total_loss_train = 0 # 한 에포크당 합산할 손실값 (나중에 평균 계산)
#     309 total_score_train = 0 # 한 에포크당 합산할 손실값 (나중에 평균 계산)
# --> 311 for X_batch, y_batch in train_DataLoader:
#     312     if MPS:
#     313         model.to(device)  # 모델을 MPS 장치로 이동
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[23], line 17, in CustomImageDataset.__getitem__(self, idx)
#      14 label = self.labels[idx]
#      16 if self.transform:
# ---> 17     input_tensor = self.transform(image)
#      19 label_tensor = torch.tensor(label, dtype=torch.float)
#      21 return input_tensor, label_tensor
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/transforms.py:354, in Resize.forward(self, img)
#     346 def forward(self, img):
#     347     """
#     348     Args:
#     349         img (PIL Image or Tensor): Image to be scaled.
#    (...)
#     352         PIL Image or Tensor: Rescaled image.
#     353     """
# --> 354     return F.resize(img, self.size, self.interpolation, self.max_size, self.antialias)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/functional.py:468, in resize(img, size, interpolation, max_size, antialias)
#     466         warnings.warn("Anti-alias option is always applied for PIL Image input. Argument antialias is ignored.")
#     467     pil_interpolation = pil_modes_mapping[interpolation]
# --> 468     return F_pil.resize(img, size=output_size, interpolation=pil_interpolation)
#     470 return F_t.resize(img, size=output_size, interpolation=interpolation.value, antialias=antialias)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torchvision/transforms/_functional_pil.py:250, in resize(img, size, interpolation)
#     247 if not (isinstance(size, list) and len(size) == 2):
#     248     raise TypeError(f"Got inappropriate size arg: {size}")
# --> 250 return img.resize(tuple(size[::-1]), interpolation)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/PIL/Image.py:2222, in Image.resize(self, size, resample, box, reducing_gap)
#    2210         self = (
#    2211             self.reduce(factor, box=reduce_box)
#    2212             if callable(self.reduce)
#    2213             else Image.reduce(self, factor, box=reduce_box)
#    2214         )
#    2215         box = (
#    2216             (box[0] - reduce_box[0]) / factor_x,
#    2217             (box[1] - reduce_box[1]) / factor_y,
#    2218             (box[2] - reduce_box[0]) / factor_x,
#    2219             (box[3] - reduce_box[1]) / factor_y,
#    2220         )
# -> 2222 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
loss_train_history = [1.3976, 1.2150, 1.1512, 1.0862, 1.0328, 0.9720, 0.9030, 0.8284, 0.7518, 0.6819, 0.6297, 0.5617, 0.5013, 0.4528, 0.4100, 0.3612, 0.3346]
loss_test_history = [1.2739, 1.2015, 1.1997, 1.1438, 1.0819, 1.0405, 1.0808, 1.0083, 1.0223, 0.9855, 1.0774, 0.9769, 0.9977, 1.0143, 1.0095, 1.1470, 1.0825]
score_train_history = [0.4707, 0.5443, 0.5694, 0.5929, 0.6124, 0.6362, 0.6591, 0.6910, 0.7189, 0.7462, 0.7602, 0.7893, 0.8116, 0.8284, 0.8486, 0.8647, 0.8754]
score_test_history = [0.5328, 0.5584, 0.5494, 0.5686, 0.5945, 0.6131, 0.6091, 0.6328, 0.6351, 0.6443, 0.6396, 0.6650, 0.6575, 0.6715, 0.6828, 0.6678, 0.6858]

result = (loss_train_history, loss_test_history, score_train_history, score_test_history)

# %%
DrawPlot(result)
plt.show()

# %%
DrawPlot(result)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 DrawPlot(result)
#       2 plt.show()
#
# NameError: name 'result' is not defined

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
model = models.efficientnet_v2_l(weights=models.EfficientNet_V2_L_Weights.IMAGENET1K_V1)

# 합성곱층 가중치 고정
for param in model.parameters():
    param.requires_grad = False

# 전결합층 가중치 변경하도록 설정
for param in model.classifier.parameters():
    param.requires_grad = True

model.classifier[1] = nn.Sequential(
    nn.Linear(model.classifier[1].in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, 8)
)

# %%
# 훈련
EPOCH = 100
SAVE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/EfficientNet'

# 옵티마이저를 모델 파라미터에 대해 초기화
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

optimizer = torch.optim.RAdam(model.parameters(), lr=0.01)

result2 = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
                  endurance_cnt = 10, view_epoch = 1, num_classes = 7, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
# Out:
# [EPOCH] : 1에서 모델 저장 완료.
# [Loss : 1/100] Train : 1.5268, Test : 1.2897
# [Score  : 1/100] Train : 0.4351, Test : 0.5516
# [EPOCH] : 2에서 모델 저장 완료.
# [Loss : 2/100] Train : 1.1483, Test : 1.1399
# [Score  : 2/100] Train : 0.5856, Test : 0.5863
# [EPOCH] : 3에서 모델 저장 완료.
# [Loss : 3/100] Train : 0.8783, Test : 0.9564
# [Score  : 3/100] Train : 0.6877, Test : 0.6659
# [EPOCH] : 4에서 모델 저장 완료.
# [Loss : 4/100] Train : 0.5392, Test : 0.8733
# [Score  : 4/100] Train : 0.8182, Test : 0.6980
# [Loss : 5/100] Train : 0.2588, Test : 0.9663
# [Score  : 5/100] Train : 0.9214, Test : 0.7027
# [Loss : 6/100] Train : 0.1306, Test : 0.9556
# [Score  : 6/100] Train : 0.9712, Test : 0.7275
# [Loss : 7/100] Train : 0.0516, Test : 0.9726
# [Score  : 7/100] Train : 0.9929, Test : 0.7394
# [Loss : 8/100] Train : 0.0367, Test : 1.0807
# [Score  : 8/100] Train : 0.9951, Test : 0.7247
# [Loss : 9/100] Train : 0.0638, Test : 1.2523
# [Score  : 9/100] Train : 0.9822, Test : 0.7111
# [Loss : 10/100] Train : 0.0464, Test : 1.2371
# [Score  : 10/100] Train : 0.9877, Test : 0.7293
# [Loss : 11/100] Train : 0.0556, Test : 1.2352
# [Score  : 11/100] Train : 0.9863, Test : 0.7288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[219], line 10
#       6 optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#       8 # optimizer = torch.optim.RAdam(model.parameters(), lr=0.001)
# ---> 10 result = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
#      11                   endurance_cnt = 10, view_epoch = 1, num_classes = 8, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
#
# File ~/WorkSpace/KDT2/MyModule/KDTModule.py:311, in training(train_DataLoader, test_DataLoader, model, model_type, optimizer, epoch, endurance_cnt, view_epoch, num_classes, SAVE_PATH, MPS, device)
#     308 total_loss_train = 0 # 한 에포크당 합산할 손실값 (나중에 평균 계산)
#     309 total_score_train = 0 # 한 에포크당 합산할 손실값 (나중에 평균 계산)
# --> 311 for X_batch, y_batch in train_DataLoader:
#     312     if MPS:
#     313         model.to(device)  # 모델을 MPS 장치로 이동
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:316, in default_collate(batch)
#     255 def default_collate(batch):
#     256     r"""
#     257     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     258
#    (...)
#     314         >>> default_collate(batch)  # Handle `CustomType` automatically
#     315     """
# --> 316     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:173, in collate(batch, collate_fn_map)
#     170 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     172 if isinstance(elem, tuple):
# --> 173     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     174 else:
#     175     try:
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:173, in <listcomp>(.0)
#     170 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     172 if isinstance(elem, tuple):
# --> 173     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     174 else:
#     175     try:
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:141, in collate(batch, collate_fn_map)
#     139 if collate_fn_map is not None:
#     140     if elem_type in collate_fn_map:
# --> 141         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     143     for collate_type in collate_fn_map:
#     144         if isinstance(elem, collate_type):
#
# File /opt/anaconda3/envs/TORCH_TEXT_38/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py:213, in collate_tensor_fn(batch, collate_fn_map)
#     211     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     212     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 213 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
loss_train_history = [1.5268, 1.1483, 0.8783, 0.5392, 0.2588, 0.1306, 0.0516, 0.0367, 0.0638, 0.0464, 0.0556]
loss_test_history = [1.2897, 1.1399, 0.9564, 0.8733, 0.9663, 0.9556, 0.9726, 1.0807, 1.2523, 1.2371, 1.2352]
score_train_history = [0.4351, 0.5856, 0.6877, 0.8182, 0.9214, 0.9712, 0.9929, 0.9951, 0.9822, 0.9877, 0.9863]
score_test_history = [0.5516, 0.5863, 0.6659, 0.6980, 0.7027, 0.7275, 0.7394, 0.7247, 0.7111, 0.7293, 0.7288]

result2 = (loss_train_history, loss_test_history, score_train_history, score_test_history)

DrawPlot(result2)
plt.show()

# %%
# DenseNet169 모델 불러오기
model = models.densenet169(weights='DEFAULT')

# 합성곱층 가중치 고정
for param in model.parameters():
    param.requires_grad = False

# 전결합층 가중치 학습 가능하도록 설정
for param in model.classifier.parameters():
    param.requires_grad = True

# 전결합층 변경
model.classifier = nn.Sequential(
    nn.Linear(model.classifier.in_features, 1024),  # 첫 번째 전결합층
    nn.ReLU(),                                      # ReLU 활성화 함수
    nn.Linear(1024, 128),                           # 두 번째 전결합층
    nn.ReLU(),                                      # ReLU 활성화 함수
    nn.Linear(128, 8)                               # 최종 출력층: 8개 클래스
)

# 훈련v
EPOCH = 100
SAVE_PATH = '/Users/anhyojun/WorkSpace/LocalData/개인 프로젝트/DenseNet'

# 옵티마이저를 모델 파라미터에 대해 초기화
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

optimizer = torch.optim.RAdam(model.parameters(), lr=0.01)

result2 = training(trainDL, validDL, model, model_type = 'multiclass', optimizer = optimizer, epoch = EPOCH,
                  endurance_cnt = 5, view_epoch = 1, num_classes = 7, SAVE_PATH = SAVE_PATH, MPS = True, device = device)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet169-b2777c0a.pth" to /Users/anhyojun/.cache/torch/hub/checkpoints/densenet169-b2777c0a.pth
# 100%|██████████| 54.7M/54.7M [00:09<00:00, 6.15MB/s]
# [EPOCH] : 1에서 모델 저장 완료.
# [Loss : 1/100] Train : 1.4090, Test : 1.3145
# [Score  : 1/100] Train : 0.4660, Test : 0.5044
